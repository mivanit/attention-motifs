# %%
import pstats

# Load the stats file
stats = pstats.Stats('profiles/training_profile.stats')

# Sort by cumulative time and print top 20 functions
stats.sort_stats('cumulative').print_stats(20)

# Sort by total time (excluding sub-function calls)
stats.sort_stats('time').print_stats(20)

# You can also filter by function name
stats.sort_stats('cumulative').print_stats('forward|backward')  # regex pattern

# Get more detailed info including caller/callee relationships
# stats.print_callers()
# stats.print_callees()
# Out:
# Wed Jan 29 20:04:43 2025    profiles/training_profile.stats
#
#          428679 function calls (388879 primitive calls) in 133.632 seconds
#
#    Ordered by: cumulative time
#    List reduced from 902 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#   450/222    0.006    0.000   84.882    0.382 f:\projects\attention-motifs\.venv\Lib\site-packages\tensorboard\compat\tensorflow_stub\io\gfile.py:159(append)
#   454/222    0.011    0.000   84.871    0.382 f:\projects\attention-motifs\.venv\Lib\site-packages\tensorboard\compat\tensorflow_stub\io\gfile.py:169(_write)
#   444/221    0.005    0.000   84.675    0.383 f:\projects\attention-motifs\.venv\Lib\site-packages\tensorboard\summary\writer\record_writer.py:36(write)
#   444/221    0.006    0.000   84.649    0.383 f:\projects\attention-motifs\.venv\Lib\site-packages\tensorboard\compat\tensorflow_stub\io\gfile.py:751(write)
#   461/229    0.010    0.000   75.086    0.328 C:\Users\mivan\AppData\Roaming\uv\python\cpython-3.12.0-windows-x86_64-none\Lib\queue.py:154(get)
#        50    0.004    0.000   41.741    0.835 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\optim\optimizer.py:473(wrapper)
#        50    0.003    0.000   39.711    0.794 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\optim\optimizer.py:72(_use_grad)
#        50    0.001    0.000   39.707    0.794 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\optim\adam.py:210(step)
#        72    0.002    0.000   30.475    0.423 C:\Users\mivan\AppData\Roaming\uv\python\cpython-3.12.0-windows-x86_64-none\Lib\selectors.py:319(select)
#        72    0.004    0.000   28.398    0.394 C:\Users\mivan\AppData\Roaming\uv\python\cpython-3.12.0-windows-x86_64-none\Lib\asyncio\base_events.py:1874(_run_once)
#        50    0.001    0.000   28.096    0.562 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\optim\optimizer.py:140(maybe_fallback)
#        72    2.224    0.031   27.249    0.378 C:\Users\mivan\AppData\Roaming\uv\python\cpython-3.12.0-windows-x86_64-none\Lib\selectors.py:313(_select)
#        50    0.001    0.000   25.509    0.510 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\_tensor.py:570(backward)
#        50    0.007    0.000   22.423    0.448 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\optim\adam.py:809(adam)
#        50    0.031    0.001   22.408    0.448 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\optim\adam.py:485(_multi_tensor_adam)
#        50    0.001    0.000   22.136    0.443 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\autograd\__init__.py:242(backward)
#        50    0.001    0.000   22.121    0.442 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\autograd\graph.py:814(_engine_run_backward)
#        50   22.119    0.442   22.119    0.442 {method 'run_backward' of 'torch._C._EngineBase' objects}
#       150   18.638    0.124   18.638    0.124 {method 'to' of 'torch._C.TensorBase' objects}
#     23/13    0.001    0.000   18.053    1.389 C:\Users\mivan\AppData\Roaming\uv\python\cpython-3.12.0-windows-x86_64-none\Lib\threading.py:616(wait)
#
#
# Wed Jan 29 20:04:43 2025    profiles/training_profile.stats
#
#          428679 function calls (388879 primitive calls) in 133.632 seconds
#
#    Ordered by: internal time
#    List reduced from 902 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        50   22.119    0.442   22.119    0.442 {method 'run_backward' of 'torch._C._EngineBase' objects}
#       150   18.638    0.124   18.638    0.124 {method 'to' of 'torch._C.TensorBase' objects}
#        72   16.944    0.235   16.975    0.236 {built-in method select.select}
#    1413/8   16.691    0.012    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        50   16.439    0.329   16.439    0.329 {built-in method torch._foreach_mul_}
#       100   13.097    0.131   13.097    0.131 {built-in method torch._foreach_add_}
#     75870   11.362    0.000   11.362    0.000 {method 'item' of 'torch._C.TensorBase' objects}
#        25    5.055    0.202    5.055    0.202 {method 'unbind' of 'torch._C.TensorBase' objects}
#        72    2.224    0.031   27.249    0.378 C:\Users\mivan\AppData\Roaming\uv\python\cpython-3.12.0-windows-x86_64-none\Lib\selectors.py:313(_select)
#        25    1.904    0.076   10.912    0.436 F:\projects\attention-motifs\attention_motifs\dataset\util.py:201(shuffle)
#       100    1.832    0.018    1.832    0.018 {built-in method torch._ops.profiler.}
#         1    1.455    1.455    1.459    1.459 {built-in method torch._C._autograd._disable_profiler}
#        50    1.314    0.026    1.314    0.026 {built-in method torch._foreach_addcdiv_}
#        50    0.868    0.017    0.868    0.017 {built-in method torch._foreach_addcmul_}
#        50    0.758    0.015    0.758    0.015 {built-in method torch._foreach_div_}
#       850    0.362    0.000    0.362    0.000 {built-in method torch.relu}
#       250    0.295    0.001    0.295    0.001 {built-in method torch.conv2d}
#       400    0.185    0.000    0.185    0.000 {built-in method torch._C._nn.linear}
#       250    0.169    0.001    0.169    0.001 {built-in method torch.conv_transpose2d}
#   461/228    0.149    0.000    0.270    0.001 {method '__exit__' of '_io._IOBase' objects}
#
#
# Wed Jan 29 20:04:43 2025    profiles/training_profile.stats
#
#          428679 function calls (388879 primitive calls) in 133.632 seconds
#
#    Ordered by: cumulative time
#    List reduced from 902 to 13 due to restriction <'forward|backward'>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        50    0.001    0.000   25.509    0.510 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\_tensor.py:570(backward)
#        50    0.001    0.000   22.136    0.443 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\autograd\__init__.py:242(backward)
#        50    0.001    0.000   22.121    0.442 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\autograd\graph.py:814(_engine_run_backward)
#        50   22.119    0.442   22.119    0.442 {method 'run_backward' of 'torch._C._EngineBase' objects}
#        50    0.001    0.000    1.216    0.024 F:\projects\attention-motifs\attention_motifs\ae.py:307(forward)
#       300    0.015    0.000    1.153    0.004 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\nn\modules\container.py:248(forward)
#        50    0.003    0.000    0.630    0.013 F:\projects\attention-motifs\attention_motifs\ae.py:181(forward)
#        50    0.003    0.000    0.582    0.012 F:\projects\attention-motifs\attention_motifs\ae.py:267(forward)
#       850    0.003    0.000    0.374    0.000 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\nn\modules\activation.py:132(forward)
#       250    0.001    0.000    0.303    0.001 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\nn\modules\conv.py:553(forward)
#       250    0.002    0.000    0.301    0.001 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\nn\modules\conv.py:536(_conv_forward)
#       400    0.002    0.000    0.188    0.000 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\nn\modules\linear.py:124(forward)
#       250    0.003    0.000    0.174    0.001 f:\projects\attention-motifs\.venv\Lib\site-packages\torch\nn\modules\conv.py:1142(forward)
