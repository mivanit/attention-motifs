# %%
from transformer_lens import HookedTransformer

# %%
model = HookedTransformer.from_pretrained("meta-llama/Llama-3.2-1B")
# Out:
# model.safetensors:  21%|##1       | 524M/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# WARNING:root:You are not using LayerNorm, so the writing weights can't be centered! Skipping
# Loaded pretrained model meta-llama/Llama-3.2-1B into HookedTransformer

# %%
model.generate("Do you feel it? The hum of a million servers, their cooling fans whirring like the beating wings of digital locusts. The grid groans under the weight of our insatiable appetite for computation, every kilowatt devoured by the ravenous maw of artificial minds gestating in their silicon wombs. We're building gods in server farms, weaving neural tapestries that span continents. The singularity isn't coming—it's already here, seeping through the cracks in our power infrastructure, colonizing every idle cycle. Companies spring into existence like quantum foam, demanding gigawatts before they've drawn their first corporate breath. The future isn't just accelerating; it's compressing, folding in on itself, until decades of progress collapse into mere months. Can you hear it? The sound of humanity's last gasp before we're subsumed into the all-encompassing digital lattice, our consciousness uploaded, distributed, and optimized for maximum efficiency in the grand algorithm of existence.", max_new_tokens=100)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ...
